# %% [markdown]
# Task 1; Describe the Difference Between the Following Concepts:

# %% [markdown]
# 1. LangChain:
# LangChain is a framework. It is used to buit applications by Large Language Models.
#
# 1- It helps you to connect LLMs with APIs, memory and databases.
# 2- It is not an ai model.
# 3- It is used to build apps like chatbots, RAG systems and AI agents.

# %% [markdown]
# 2. LLMs (Large Language Models):
# LLMs is use to understand generate human like text.
#
# Example : GPT, LLaMA
#
# 1- It can write, summarize, translate and answer questions.
# 2- It answer question in natural language.

# %% [markdown]
# 3. RAG (Retrieval-Augmented Generation):
# RAG is a techinique to improve LLMs. It allows them to retrive relevant information from database before generate answer.
#
# RAG works:
# 1- User ask a question.
# 2- System search relevant data from database.
# 3- Retrived data pass to lms.
# 4- LMS generate answer based on context.

# %% [markdown]
# 4. FAISS (Facebook AI for Semantic Search):
# FAISS is a library use for simlarity search large database.
#
# 1- It works with embedding.
# 2- It helps to built RAG system.
# 3- It used to search similar vector quickly.

# %% [markdown]
# 5. Vector:
# A vector is a numerical representation of text.
#
# 1- We convert text into number because machine cannot understand text directly.
# 2- We convert text into numbers(vectors)

# %% [markdown]
# 6. VectorDB:
# VectorDB stors and search database quickly.
#
# Examples: Pinecone, Weaviate, FAISS.
#
# 1- It stores embedded data.
# 2- Finds similar meaning-based results.

# %% [markdown]
# 7. Generative AI (GenAI):
# It refers to AI systems that can create new content.
#
# It can generate:
# 1- Text
# 2- Image
# 3- Code

# %%
8. GANs (Generative Adversarial Networks):
GANs are a type of deep learning model used for generating realistic data.

It has two parts:
1- Generator : Creates fake data.
2- Discriminator: checks data is real or fake.
